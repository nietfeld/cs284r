# %% [markdown]
# # Homework 5: Networks and Congress
#
# *Due Friday, November 15, 11:59pm*
#
# <img src="http://img.washingtonpost.com/rf/image_1024w/2010-2019/WashingtonPost/2011/08/05/National-Politics/Images/uscap.JPG">
#
# <br>

# %%
# %matplotlib inline

import json

import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt
import operator
import json

# set some nicer defaults for matplotlib
from matplotlib import rcParams

#these colors come from colorbrewer2.org. Each is an RGB triplet
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843),
                (0.4, 0.4, 0.4)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.grid'] = False
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'none'

def remove_border(axes=None, top=False, right=False, left=True, bottom=True):
    """
    Minimize chartjunk by stripping out unnecessary plot borders and axis ticks
    
    The top/right/left/bottom keywords toggle whether the corresponding plot border is drawn
    """
    ax = axes or plt.gca()
    ax.spines['top'].set_visible(top)
    ax.spines['right'].set_visible(right)
    ax.spines['left'].set_visible(left)
    ax.spines['bottom'].set_visible(bottom)
    
    #turn off all ticks
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.set_ticks_position('none')
    
    #now re-enable visibles
    if top:
        ax.xaxis.tick_top()
    if bottom:
        ax.xaxis.tick_bottom()
    if left:
        ax.yaxis.tick_left()
    if right:
        ax.yaxis.tick_right()

# %% [markdown]
# The website [govtrack.us](http://www.govetrack.us) collects data on activities in the Senate and House of Representatives. It's a great source of information for making data-driven assessments about Congress.

# %% [markdown]
# ### Problem 1.
#
# The directories at http://www.govtrack.us/data/congress/113/votes/2013 contain JSON information about every vote cast for the current (113th)  Congress. Subdirectories beginning with "S" correspond to Senate votes, while subdirectories beginning with "H" correspond to House votes.
#
# Write two functions: one that downloads and parses a single Senate vote page given the vote number, and another that repeatedly calls this function to build a full collection of Senate votes from the 113th Congress.

# %%
"""
Function
--------
get_senate_vote

Scrapes a single JSON page for a particular Senate vote, given by the vote number

Parameters
----------
vote : int
   The vote number to fetch
   
Returns
-------
vote : dict
   The JSON-decoded dictionary for that vote
   
Examples
--------
>>> get_senate_vote(11)['bill']
{u'congress': 113,
 u'number': 325,
 u'title': u'A bill to ensure the complete and timely payment of the obligations of the United States Government until May 19, 2013, and for other purposes.',
 u'type': u'hr'}
"""
import json
vote_url = "https://www.govtrack.us/data/congress/113/votes/2013"

def get_senate_vote(number): 
    vote_page = vote_url+"/s"+str(number)+"/data.json"
    vote_dict = requests.get(vote_page).json()
    return vote_dict

def get_house_vote(number): 
    vote_page = vote_url+"/h"+str(number)+"/data.json"
    vote_dict = requests.get(vote_page).json()
    return vote_dict

# %%
"""
Function
--------
get_all_votes

Scrapes all the Senate votes from http://www.govtrack.us/data/congress/113/votes/2013,
and returns a list of dicts

Parameters
-----------
None

Returns
--------
votes : list of dicts
    List of JSON-parsed dicts for each senate vote
"""

import pattern.web as web

def get_all_votes():
    dict_list = []
    vote_page = requests.get(vote_url).text
    element = web.Element(vote_page)
    link_list = element.by_tag("a") 
    for link in link_list: 
        label=link[0]
        if str(label)[0] == "s": 
            dict_list.append(get_senate_vote(str(label)[1:-1]))
    return dict_list

def get_all_house_votes(): 
    dict_list = []
    vote_page = requests.get(vote_url).text
    element = web.Element(vote_page)
    link_list = element.by_tag("a") 
    for link in link_list: 
        label=link[0]
        if str(label)[0] == "h": 
            dict_list.append(get_house_vote(str(label)[1:-1]))
    return dict_list

# %%
# download bills and dump into file
"""
vote_data = get_all_votes()
house_vote_data = get_all_house_votes()

with open('senate_data.txt', 'w') as outfile:
  json.dump(vote_data, outfile)
with open('house_data.txt', 'w') as outfile:
  json.dump(house_vote_data, outfile)
"""

# %%
# Loading info from files 

json_data=open('house_data.txt')
house_vote_data = json.load(json_data)
json_data.close()

json_data=open('senate_data.txt')
vote_data = json.load(json_data)
json_data.close()

# %%
print vote_data[0]
# Out:
# {u'category': u'passage', u'votes': {u'Yea': [{u'first_name': u'Lamar', u'last_name': u'Alexander', u'display_name': u'Alexander (R-TN)', u'state': u'TN', u'party': u'R', u'id': u'S289'}, {u'first_name': u'Kelly', u'last_name': u'Ayotte', u'display_name': u'Ayotte (R-NH)', u'state': u'NH', u'party': u'R', u'id': u'S340'}, {u'first_name': u'Tammy', u'last_name': u'Baldwin', u'display_name': u'Baldwin (D-WI)', u'state': u'WI', u'party': u'D', u'id': u'S354'}, {u'first_name': u'John', u'last_name': u'Barrasso', u'display_name': u'Barrasso (R-WY)', u'state': u'WY', u'party': u'R', u'id': u'S317'}, {u'first_name': u'Max', u'last_name': u'Baucus', u'display_name': u'Baucus (D-MT)', u'state': u'MT', u'party': u'D', u'id': u'S127'}, {u'first_name': u'Mark', u'last_name': u'Begich', u'display_name': u'Begich (D-AK)', u'state': u'AK', u'party': u'D', u'id': u'S319'}, {u'first_name': u'Michael', u'last_name': u'Bennet', u'display_name': u'Bennet (D-CO)', u'state': u'CO', u'party': u'D', u'id': u'S330'}, {u'first_name': u'Richard', u'last_name': u'Blumenthal', u'display_name': u'Blumenthal (D-CT)', u'state': u'CT', u'party': u'D', u'id': u'S341'}, {u'first_name': u'Roy', u'last_name': u'Blunt', u'display_name': u'Blunt (R-MO)', u'state': u'MO', u'party': u'R', u'id': u'S342'}, {u'first_name': u'John', u'last_name': u'Boozman', u'display_name': u'Boozman (R-AR)', u'state': u'AR', u'party': u'R', u'id': u'S343'}, {u'first_name': u'Barbara', u'last_name': u'Boxer', u'display_name': u'Boxer (D-CA)', u'state': u'CA', u'party': u'D', u'id': u'S223'}, {u'first_name': u'Sherrod', u'last_name': u'Brown', u'display_name': u'Brown (D-OH)', u'state': u'OH', u'party': u'D', u'id': u'S307'}, {u'first_name': u'Maria', u'last_name': u'Cantwell', u'display_name': u'Cantwell (D-WA)', u'state': u'WA', u'party': u'D', u'id': u'S275'}, {u'first_name': u'Ben', u'last_name': u'Cardin', u'display_name': u'Cardin (D-MD)', u'state': u'MD', u'party': u'D', u'id': u'S308'}, {u'first_name': u'Thomas', u'last_name': u'Carper', u'display_name': u'Carper (D-DE)', u'state': u'DE', u'party': u'D', u'id': u'S277'}, {u'first_name': u'Bob', u'last_name': u'Casey', u'display_name': u'Casey (D-PA)', u'state': u'PA', u'party': u'D', u'id': u'S309'}, {u'first_name': u'Thad', u'last_name': u'Cochran', u'display_name': u'Cochran (R-MS)', u'state': u'MS', u'party': u'R', u'id': u'S136'}, {u'first_name': u'Susan', u'last_name': u'Collins', u'display_name': u'Collins (R-ME)', u'state': u'ME', u'party': u'R', u'id': u'S252'}, {u'first_name': u'Christopher', u'last_name': u'Coons', u'display_name': u'Coons (D-DE)', u'state': u'DE', u'party': u'D', u'id': u'S337'}, {u'first_name': u'Bob', u'last_name': u'Corker', u'display_name': u'Corker (R-TN)', u'state': u'TN', u'party': u'R', u'id': u'S310'}, {u'first_name': u'John', u'last_name': u'Cornyn', u'display_name': u'Cornyn (R-TX)', u'state': u'TX', u'party': u'R', u'id': u'S287'}, {u'first_name': u'Joe', u'last_name': u'Donnelly', u'display_name': u'Donnelly (D-IN)', u'state': u'IN', u'party': u'D', u'id': u'S356'}, {u'first_name': u'Richard', u'last_name': u'Durbin', u'display_name': u'Durbin (D-IL)', u'state': u'IL', u'party': u'D', u'id': u'S253'}, {u'first_name': u'Michael', u'last_name': u'Enzi', u'display_name': u'Enzi (R-WY)', u'state': u'WY', u'party': u'R', u'id': u'S254'}, {u'first_name': u'Dianne', u'last_name': u'Feinstein', u'display_name': u'Feinstein (D-CA)', u'state': u'CA', u'party': u'D', u'id': u'S221'}, {u'first_name': u'Deb', u'last_name': u'Fischer', u'display_name': u'Fischer (R-NE)', u'state': u'NE', u'party': u'R', u'id': u'S357'}, {u'first_name': u'Al', u'last_name': u'Franken', u'display_name': u'Franken (D-MN)', u'state': u'MN', u'party': u'D', u'id': u'S332'}, {u'first_name': u'Kirsten', u'last_name': u'Gillibrand', u'display_name': u'Gillibrand (D-NY)', u'state': u'NY', u'party': u'D', u'id': u'S331'}, {u'first_name': u'Chuck', u'last_name': u'Grassley', u'display_name': u'Grassley (R-IA)', u'state': u'IA', u ...

# %% [markdown]
# ### Problem 2
#
# Now, turn these data into a NetworkX graph, according to the spec below. For details on using NetworkX, consult the lab materials for November 1, as well as the [NetworkX documentation](http://networkx.github.io/).

# %%
"""
Function
--------
vote_graph

Parameters
----------
data : list of dicts
    The vote database returned from get_vote_data

Returns
-------
graph : NetworkX Graph object, with the following properties
    1. Each node in the graph is labeled using the `display_name` of a Senator (e.g., 'Lee (R-UT)')
    2. Each node has a `color` attribute set to 'r' for Republicans, 
       'b' for Democrats, and 'k' for Independent/other parties.
    3. The edges between two nodes are weighted by the number of 
       times two senators have cast the same Yea or Nay vote
    4. Each edge also has a `difference` attribute, which is set to `1 / weight`.

Examples
--------
>>> graph = vote_graph(vote_data)
>>> graph.node['Lee (R-UT)']
{'color': 'r'}  # attributes for this senator
>>> len(graph['Lee (R-UT)']) # connections to other senators
101
>>> graph['Lee (R-UT)']['Baldwin (D-WI)']  # edge relationship between Lee and Baldwin
{'difference': 0.02, 'weight': 50}
"""
import itertools 

def add_edges(g, senators): 
    
    for senator in senators: 
        
        if senator["party"] == "D": 
            color = "b"
        elif senator["party"] == "R" : 
            color = "r"
        else : 
            color = "k"
        g.add_node(senator["display_name"], color=color)
        
    # create a list of all the pairs of senators
    senator_pairs = list(itertools.combinations([x["display_name"] for x in senators], r=2))
    for sen1, sen2 in senator_pairs: 
        #increment or add an edge
        if g.has_edge(sen1, sen2): 
            g[sen1][sen2]['weight'] = (g[sen1][sen2]['weight'] + 1)
            g.edge[sen1][sen2]['difference'] = (1./g.edge[sen1][sen2]['weight'])
        else:
            g.add_edge(sen1, sen2, weight=1)
    return g
    
        
def vote_graph(data): 
    graph = nx.Graph()
    
    for vote in data: 
        graph = add_edges(graph, vote["votes"]["Yea"])
        graph = add_edges(graph, vote["votes"]["Nay"])
    
    return graph

# %%
votes = vote_graph(vote_data)

# %% [markdown]
# ### How (and how not) to visualize networks
#
# Network plots often *look* impressive, but creating sensible network plots is tricky. From Ben Fry, the author of the Processing program:
# <blockquote>
# Usually a graph layout isn’t the best option for data sets larger than a few dozen nodes. You’re most likely to wind up with enormous spider webs or balls of string, and the mess seen so far is more often the case than not. Graphs can be a powerful way to represent relationships between data, but they are also a very abstract concept, which means that they run the danger of meaning something only to the creator of the graph. Often, simply showing the structure of the data says very little about what it actually means, even though it’s a perfectly accurate means of representing the data. Everything looks like a graph, but almost nothing should ever be drawn as one.
# </blockquote>
#
# Let's look at bad and better ways of visualizing the senate vote network.
#
# First, consider the "default" plot from networkx.

# %%
#this makes sure draw_spring results are the same at each call
np.random.seed(1)  

color = [votes.node[senator]['color'] for senator in votes.nodes()]

#determine position of each node using a spring layout
pos = nx.spring_layout(votes, iterations=200)

#plot the edges
nx.draw_networkx_edges(votes, pos, alpha = .05)

#plot the nodes
nx.draw_networkx_nodes(votes, pos, node_color=color)

#draw the labels
lbls = nx.draw_networkx_labels(votes, pos, alpha=5, font_size=8)

#coordinate information is meaningless here, so let's remove it
plt.xticks([])
plt.yticks([])
remove_border(left=False, bottom=False)

# %% [markdown]
# The spring layout tries to group nodes with large edge-weights near to each other. In this context, that means it tries to organize the Senate into similarly-voting cliques. However, there's simply too much going on in this plot -- we should simplify the representation.

# %% [markdown]
# ### Problem 3
#
# Compute the `Minimum Spanning Tree` of this graph, using the `difference` edge attribute as the weight to minimize. A [Minimum Spanning Tree](http://en.wikipedia.org/wiki/Minimum_spanning_tree) is the subset of edges which trace at least one path through all nodes ("spanning"), with minimum total edge weight. You can think of it as a simplification of a network.
#
# Plot this new network, making modifications as necessary to prevent the graph from becoming too busy.

# %%
mst = nx.minimum_spanning_tree(votes, weight='distance')


#this makes sure draw_spring results are the same at each call
np.random.seed(1)  

color = [mst.node[senator]['color'] for senator in mst.nodes()]

#determine position of each node using a spring layout
pos = nx.spring_layout(mst, iterations=2000, k=.50)

#plot the edges
nx.draw_networkx_edges(mst, pos, alpha = .05)

#plot the nodes
nx.draw_networkx_nodes(mst, pos, node_color=color)

#draw the labels
lbls = nx.draw_networkx_labels(mst, pos, alpha=5, font_size=8)

#coordinate information is meaningless here, so let's remove it
plt.xticks([])
plt.yticks([])
remove_border(left=False, bottom=False)

# %% [markdown]
# ### Problem 4
#
# While this graph has less information, the remaining information is easier to digest. What does the Minimum Spanning Tree mean in this context? How does this graph relate to partisanship in the Senate? Which nodes in this graph are the most and least bi-partisan?

# %% [markdown]
# The minimum spanning tree is the closest connections between all senators. We built up the tree by selecting the edge with the most votes in common and a senator not yet in the graph until every senator was included.
#
# The nodes with the most connections are the most bipartison while the nodes at the bottom of the tree (only one connection). In the center, we have Alexander who is "The most bipartisan" according to this measure. On the outskirts we have the beleagured senators of NJ and MA who didn't stick around for very long. This graph really isn't fair to them, just because they weren't around long. Sucks to be them.
#
# Since the tree is not very deep, we don't really have too much information about the most and the least bipartisan. It looks like democrats have smaller difference scores than republicans (which you expect from the majority party). There are no really obvious partisans.

# %% [markdown]
# ### Problem 5
#
# (For this problem, use the full graph for centrality computation, and not the Minimum Spanning Tree)
#
# Networkx can easily compute [centrality](https://en.wikipedia.org/wiki/Centrality) measurements.
#
# Briefly discuss what ``closeness_centrality`` means, both mathematically and in the context of the present graph -- how does the centrality relate to partisanship? Choose a way to visualize the `closeness_centrality` score for each member of the Senate, using edge `difference` as the distance measurement. Determine the 5 Senators with the highest and lowest centralities.
#
# Comment on your results. In particular, note the outliers John Kerry (who recently resigned his Senate seat when he became Secretary of State), Mo Cowan (Kerry's interim replacement) and Ed Markey (Kerry's permanent replacement) have low centrality scores -- why?

# %% [markdown]
# Mathematically, closeless centrality is the inverse of the sum of the distances to other nodes. The more central a node is the lower its total distance to all other nodes. If we were going to measure how long it would take to spread information from one node to all the others sequentially, closeness centrality would measure that.
#
# With regards to this graph, closeness centrality relates to partisanship, since a high score means a candidate is close to every other politician in the graph, in both parties.
#
# We notice that the people with the lowest closeness score only served part of their term in the senate. With fewer votes cast, they had many fewer oportunities to vote "Yea" or "Nay" with others on bills. Since this in not accounted for, it looks as though these politicians are incredibly partisan, when in fact they are just new.

# %%
#calculate centrality 
closeness_dict = nx.closeness_centrality(votes, distance="difference")
sorted_closenesses = sorted(closeness_dict.iteritems(), key=operator.itemgetter(1))
sorted_keys = [x[0] for x in sorted_closenesses]
sorted_values = [x[1] for x in sorted_closenesses]
color = [mst.node[senator]['color'] for senator in bipartisan_votes.nodes()]


#visualize centrality
fig = plt.figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(111)

plt.bar(range(len(sorted_keys)), sorted_values, align='center', color=color)
plt.xticks(range(len(sorted_keys)), sorted_keys, rotation=80, fontsize='small')
plt.show()

print "Lowest closeness_centrality scores:" 
for senator in sorted_closenesses[0:5]: 
    print "%s : %s" % (senator[0], senator[1]) 

print
    
#TO DO REVERSE 
print "Highest closeness_centrality scores:"
for senator in sorted_closenesses[-5:]: 
    print "%s : %s" % (senator[0], senator[1])
# Out:
# Lowest closeness_centrality scores:
# Kerry (D-MA) : 3.9392101474
# Booker (D-NJ) : 8.461282037
# Lautenberg (D-NJ) : 24.9940966601
# Chiesa (R-NJ) : 38.8260605147
# Markey (D-MA) : 40.5516800231
#
# Highest closeness_centrality scores:
# Donnelly (D-IN) : 90.1382343087
# Hagan (D-NC) : 90.482630858
# Pryor (D-AR) : 90.970781304
# Manchin (D-WV) : 92.02418544
# Collins (R-ME) : 94.5927162526

# %% [markdown]
# ### Problem 6
#
# Centrality isn't a perfect proxy for bipartisanship, since it gauges how centralized a node is to the network as a whole, and not how similar a Democrat node is to the Republican sub-network (and vice versa).
#
# Can you come up with another measure that better captures bipartisanship than closeness centrality? Develop your own metric -- how does it differ from the closeness centrality? Use visualizations to support your points.

# %%
import itertools 

def add_bipartisan_edges(g, senators): 
    
    for senator in senators: 
        if senator["party"] == "D": 
            color = "b"
        elif senator["party"] == "R" : 
            color = "r"
        else : 
            color = "k"
        g.add_node(senator["display_name"], color=color)
        
    # create a list of all the pairs of senators
    senator_pairs = list(itertools.combinations([(x["display_name"], x['party']) for x in senators], r=2))
    for (sen1, sen1party), (sen2, sen2party) in senator_pairs: 
        # check if the senators are in different parties
        if (sen1party != sen2party): # and (sen1party == ("D" or "R")) and (sen2party == ("D" or "R")): 
            #increment or add an edge
            if g.has_edge(sen1, sen2): 
                g[sen1][sen2]['weight'] = (g[sen1][sen2]['weight'] + 1)
                g.edge[sen1][sen2]['difference'] = (1./g.edge[sen1][sen2]['weight'])
            else:
                g.add_edge(sen1, sen2, weight=1)
    return g
        
def bipartisan_graph(data): 
    graph = nx.Graph()
    
    for vote in data: 
        graph = add_bipartisan_edges(graph, vote["votes"]["Yea"])
        graph = add_bipartisan_edges(graph, vote["votes"]["Nay"])
    
    return graph

all_bipartisan_votes = bipartisan_graph(vote_data) 
bipartisan_votes = nx.minimum_spanning_tree(all_bipartisan_votes, weight='distance')
 

#this makes sure draw_spring results are the same at each call
np.random.seed(1)  

color = [mst.node[senator]['color'] for senator in bipartisan_votes.nodes()]

#determine position of each node using a spring layout
pos = nx.spring_layout(bipartisan_votes, iterations=500, k=.45)

#plot the edges
nx.draw_networkx_edges(bipartisan_votes, pos, alpha = .05)

#plot the nodes
nx.draw_networkx_nodes(bipartisan_votes, pos, node_color=color)

#draw the labels
lbls = nx.draw_networkx_labels(bipartisan_votes, pos, alpha=5, font_size=8)

#coordinate information is meaningless here, so let's remove it
plt.xticks([])
plt.yticks([])
remove_border(left=False, bottom=False)

# %% [markdown]
# Instead of just seeing how close one node is to all other nodes, we can look at how often a senator votes the same way on a bill as did someone from a different party. We calculate the relationship between senators from different parties in much the same way as we did problem 2 and then calculate the MST (which represents pairs of people from  different parties who vote the most similarly.)
#
# We see them clustered around a few key politians: Alexander (not surprising), the independents (democrats in disguise) and Amy Klobuchar (from my fine home state). We should have filtered out the independents, since they seem to always vote with democrats. But the relation to Amy Klobuchar is interesting and the criteria of voting on other parties' bills seems promising.

# %% [markdown]
# ## Leadership in the Senate
#
# There are many metrics to quantify the leadership in the Senate.
#
#   1. Senate leaders sponsor and co-sponsor lots of bills
#   2. Leaders sit on many committees, as well as more important committees
#   3. Leaders usually have been in office for a long time
#
# Another approach uses the philosophy behind how Google ranks search results. The core idea behind Google's PageRank algorithm is:
#
# 1. A "good" website (i.e. one to rank highly in search results) is linked to by many other websites
# 2. A link found on a "good" website is more important than a link found on a "bad" website
#
# The PageRank algorithm thus assigns scores to nodes in a graph based on how many neighbors a node has, as well as the score of those neighbors.
#
# This technique can be adapted to rank Senate leadership. Here, nodes correspond to Senators, and edges correspond to a senator co-sponsoring a bill sponsored by another Senator. The weight of each edge from node A to B is the number of times Senator A has co-sponsored a bill whose primary sponsor is Senator B. If you interpret the PageRank scores of such a network to indicate Senate leadership, you are then assuming:
#
# 1. Leaders sponsor more bills
# 1. Leaders attract co-sponsorship from other leaders
#
# ### Problem 7
#
# Govtrack stores information about each Senate bill in the current congress at http://www.govtrack.us/data/congress/113/bills/s/. As in problem 1, write two functions to scrape these data -- the first function downloads a single bill, and the second function calls the first to loop over all bills.

# %%
"""
Function
--------
get_senate_bill

Scrape the bill data from a single JSON page, given the bill number

Parameters
-----------
bill : int
   Bill number to fetch
   
Returns
-------
A dict, parsed from the JSON

Examples
--------
>>> bill = get_senate_bill(10)
>>> bill['sponsor']
{u'district': None,
 u'name': u'Reid, Harry',
 u'state': u'NV',
 u'thomas_id': u'00952',
 u'title': u'Sen',
 u'type': u'person'}
>>> bill['short_title']
u'Agriculture Reform, Food, and Jobs Act of 2013'
"""

bill_url = "http://www.govtrack.us/data/congress/113/bills/s/"
    
def get_senate_bill(number): 
    bill_page = bill_url+"/s"+str(number)+"/data.json"
    print bill_page
    bill_dict = requests.get(bill_page).json()
    return bill_dict

# %%
"""
Function
--------
get_all_bills

Scrape all Senate bills at http://www.govtrack.us/data/congress/113/bills/s

Parameters
----------
None

Returns
-------
A list of dicts, one for each bill
"""
def get_all_bills():
    dict_list = []
    bill_list = requests.get(bill_url).text
    element = web.Element(bill_list)
    link_list = element.by_tag("a") 
    for link in link_list: 
        label=link[0]
        if str(label)[0] == "s": 
            dict_list.append(get_senate_bill(str(label)[1:-1]))
    return dict_list

# %%
bill_list = get_all_bills()
# Out:
# http://www.govtrack.us/data/congress/113/bills/s//s1/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s10/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s100/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1000/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1001/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1002/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1003/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1004/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1005/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1006/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1007/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1008/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1009/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s101/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1010/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1011/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1012/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1013/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1014/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1015/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1016/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1017/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1018/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1019/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s102/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1020/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1021/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1022/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1023/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1024/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1025/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1026/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1027/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1028/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1029/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s103/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1030/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1031/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1032/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1033/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1034/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1035/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1036/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1037/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1038/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1039/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s104/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1040/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1041/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1042/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1043/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1044/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1045/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1046/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1047/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1048/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1049/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s105/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1050/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1051/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1052/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1053/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1054/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1055/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1056/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1057/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1058/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1059/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s106/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1060/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1061/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1062/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1063/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1064/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1065/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1066/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1067/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1068/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1069/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s107/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1070/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1071/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1072/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1073/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1074/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1075/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1076/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1077/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1078/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1079/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s108/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1080/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1081/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1082/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1083/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1084/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1085/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1086/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1087/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1088/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1089/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s109/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1090/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1091/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1092/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1093/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1094/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1095/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1096/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1097/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1098/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1099/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s11/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s110/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1100/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1101/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1102/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1103/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1104/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1105/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1106/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1107/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1108/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1109/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s111/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1110/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1111/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1112/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1113/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1114/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1115/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1116/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1117/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1118/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1119/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s112/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1120/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1121/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1122/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1123/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1124/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1125/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1126/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1127/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1128/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1129/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s113/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1130/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1131/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1132/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1133/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1134/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1135/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1136/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1137/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1138/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1139/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s114/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1140/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1141/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1142/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1143/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1144/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1145/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1146/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1147/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1148/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1149/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s115/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1150/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1151/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1152/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1153/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1154/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1155/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1156/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1157/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1158/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1159/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s116/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1160/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1161/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1162/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1163/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1164/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1165/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1166/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1167/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1168/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1169/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s117/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1170/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1171/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1172/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1173/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1174/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1175/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1176/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1177/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1178/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1179/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s118/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1180/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1181/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1182/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1183/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1184/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1185/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1186/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1187/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1188/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1189/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s119/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1190/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1191/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1192/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1193/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1194/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1195/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1196/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1197/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1198/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1199/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s12/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s120/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1200/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1201/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1202/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1203/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1204/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1205/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1206/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1207/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1208/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1209/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s121/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1210/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1211/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1212/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1213/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1214/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1215/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1216/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1217/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1218/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1219/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s122/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1220/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1221/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1222/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1223/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1224/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1225/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1226/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1227/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1228/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1229/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s123/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1230/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1231/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1232/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1233/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1234/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1235/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1236/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1237/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1238/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1239/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s124/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1240/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1241/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1242/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1243/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1244/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1245/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1246/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1247/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1248/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1249/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s125/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1250/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1251/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1252/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1253/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1254/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1255/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1256/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1257/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1258/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1259/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s126/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1260/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1261/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1262/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1263/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1264/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1265/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1266/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1267/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1268/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1269/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s127/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1270/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1271/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1272/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1273/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1274/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1275/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1276/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1277/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1278/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1279/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s128/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1280/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1281/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1282/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1283/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1284/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1285/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1286/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1287/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1288/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1289/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s129/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1290/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1291/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1292/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1293/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1294/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1295/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1296/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1297/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1298/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1299/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s13/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s130/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1300/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1301/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1302/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1303/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1304/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1305/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1306/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1307/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1308/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1309/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s131/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1310/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1311/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1312/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1313/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1314/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1315/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1316/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1317/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1318/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1319/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s132/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1320/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1321/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1322/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1323/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1324/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1325/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1326/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1327/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1328/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1329/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s133/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1330/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1331/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1332/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1333/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1334/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1335/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1336/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1337/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1338/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1339/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s134/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1340/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1341/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1342/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1343/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1344/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1345/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1346/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1347/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1348/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1349/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s135/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1350/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1351/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1352/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1353/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1354/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1355/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1356/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1357/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1358/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1359/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s136/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1360/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1361/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1362/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1363/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1364/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1365/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1366/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1367/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1368/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1369/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s137/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1370/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1371/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1372/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1373/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1374/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1375/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1376/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1377/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1378/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1379/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s138/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1380/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1381/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1382/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1383/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1384/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1385/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1386/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1387/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1388/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1389/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s139/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1390/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1391/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1392/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1393/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1394/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1395/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1396/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1397/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1398/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1399/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s14/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s140/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1400/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1401/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1402/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1403/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1404/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1405/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1406/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1407/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1408/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1409/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s141/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1410/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1411/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1412/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1413/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1414/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1415/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1416/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1417/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1418/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1419/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s142/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1420/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1421/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1422/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1423/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1424/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1425/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1426/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1427/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1428/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1429/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s143/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1430/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1431/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1432/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1433/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1434/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1435/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1436/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1437/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1438/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1439/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s144/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1440/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1441/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1442/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1443/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1444/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1445/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1446/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1447/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1448/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1449/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s145/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1450/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1451/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1452/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1453/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1454/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1455/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1456/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1457/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1458/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1459/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s146/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1460/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1461/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1462/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1463/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1464/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1465/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1466/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1467/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1468/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1469/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s147/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1470/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1471/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1472/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1473/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1474/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1475/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1476/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1477/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1478/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1479/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s148/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1480/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1481/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1482/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1483/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1484/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1485/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1486/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1487/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1488/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1489/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s149/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1490/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1491/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1492/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1493/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1494/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1495/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1496/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1497/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1498/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1499/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s15/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s150/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1500/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1501/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1502/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1503/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1504/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1505/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1506/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1507/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1508/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1509/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s151/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1510/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1511/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1512/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1513/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1514/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1515/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1516/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1517/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1518/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1519/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s152/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1520/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1521/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1522/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1523/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1524/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1525/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1526/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1527/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1528/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1529/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s153/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1530/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1531/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1532/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1533/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1534/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1535/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1536/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1537/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1538/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1539/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s154/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1540/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1541/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1542/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1543/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1544/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1545/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1546/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1547/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1548/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1549/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s155/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1550/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1551/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1552/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1553/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1554/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1555/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1556/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1557/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1558/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1559/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s156/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1560/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1561/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1562/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1563/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1564/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1565/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1566/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1567/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1568/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1569/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s157/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1570/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1571/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1572/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1573/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1574/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1575/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1576/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1577/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1578/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1579/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s158/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1580/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1581/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1582/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1583/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1584/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1585/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1586/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1587/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1588/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1589/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s159/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1590/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1591/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1592/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1593/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1594/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1595/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1596/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1597/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1598/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1599/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s16/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s160/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1600/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1601/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1602/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1603/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1604/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1605/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1606/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1607/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1608/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1609/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s161/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1610/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1611/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1612/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1613/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1614/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1615/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1616/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1617/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1618/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1619/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s162/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1620/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1621/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1622/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1623/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1624/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1625/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1626/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1627/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1628/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1629/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s163/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1630/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1631/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1632/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1633/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1634/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1635/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1636/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1637/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1638/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1639/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s164/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1640/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1641/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1642/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1643/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1644/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1645/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1646/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1647/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1648/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1649/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s165/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1650/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1651/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1652/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s1653/data.json
# ...
# http://www.govtrack.us/data/congress/113/bills/s//s778/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s779/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s78/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s780/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s781/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s782/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s783/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s784/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s785/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s786/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s787/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s788/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s789/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s79/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s790/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s791/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s792/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s793/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s794/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s795/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s796/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s797/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s798/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s799/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s8/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s80/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s800/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s801/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s802/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s803/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s804/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s805/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s806/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s807/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s808/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s809/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s81/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s810/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s811/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s812/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s813/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s814/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s815/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s816/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s817/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s818/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s819/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s82/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s820/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s821/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s822/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s823/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s824/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s825/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s826/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s827/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s828/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s829/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s83/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s830/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s831/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s832/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s833/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s834/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s835/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s836/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s837/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s838/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s839/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s84/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s840/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s841/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s842/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s843/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s844/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s845/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s846/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s847/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s848/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s849/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s85/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s850/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s851/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s852/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s853/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s854/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s855/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s856/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s857/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s858/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s859/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s86/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s860/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s861/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s862/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s863/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s864/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s865/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s866/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s867/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s868/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s869/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s87/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s870/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s871/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s872/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s873/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s874/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s875/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s876/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s877/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s878/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s879/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s88/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s880/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s881/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s882/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s883/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s884/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s885/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s886/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s887/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s888/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s889/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s89/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s890/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s891/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s892/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s893/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s894/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s895/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s896/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s897/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s898/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s899/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s9/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s90/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s900/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s901/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s902/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s903/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s904/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s905/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s906/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s907/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s908/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s909/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s91/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s910/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s911/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s912/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s913/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s914/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s915/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s916/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s917/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s918/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s919/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s92/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s920/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s921/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s922/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s923/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s924/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s925/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s926/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s927/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s928/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s929/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s93/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s930/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s931/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s932/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s933/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s934/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s935/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s936/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s937/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s938/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s939/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s94/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s940/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s941/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s942/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s943/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s944/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s945/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s946/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s947/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s948/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s949/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s95/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s950/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s951/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s952/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s953/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s954/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s955/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s956/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s957/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s958/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s959/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s96/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s960/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s961/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s962/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s963/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s964/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s965/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s966/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s967/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s968/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s969/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s97/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s970/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s971/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s972/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s973/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s974/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s975/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s976/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s977/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s978/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s979/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s98/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s980/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s981/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s982/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s983/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s984/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s985/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s986/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s987/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s988/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s989/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s99/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s990/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s991/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s992/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s993/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s994/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s995/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s996/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s997/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s998/data.json
# http://www.govtrack.us/data/congress/113/bills/s//s999/data.json

# %% [markdown]
# ### Problem 8
#
# Write a function to builded a Directed Graph (DiGraph) from these data, according to the following spec:

# %%
"""
Function
--------
bill_graph

Turn the bill graph data into a NetworkX Digraph

Parameters
----------
data : list of dicts
    The data returned from get_all_bills

Returns
-------
graph : A NetworkX DiGraph, with the following properties
    * Each node is a senator. For a label, use the 'name' field 
      from the 'sponsor' and 'cosponsors' dict items
    * Each edge from A to B is assigned a weight equal to how many 
      bills are sponsored by B and co-sponsored by A
"""

def add_sponsors(g, bill): 
    sponsor = bill['sponsor']['name']
    cosponsors = [x['name'] for x in bill['cosponsors']]

    for cosponsor in cosponsors:
        if g.has_edge(cosponsor, sponsor): 
            g[cosponsor][sponsor]['weight'] = (g[cosponsor][sponsor]['weight'] + 1)
        else:
            g.add_edge(cosponsor, sponsor, weight=1)
    return g
        
def bill_graph(data): 
    graph = nx.DiGraph()
    
    for bill in data: 
        graph = add_sponsors(graph, bill)
    
    return graph

# %%
bills = bill_graph(bill_list)

# %% [markdown]
# ### Problem 9
#
# Using `nx.pagerank_numpy`, compute the PageRank score for each senator in this graph. Visualize the results. Determine the 5 Senators with the highest
# PageRank scores. How effective is this approach at identifying leaders? How does the PageRank rating compare to the degree of each node?
#
# Note: you can read about individual Senators by searching for them on the [govtrack website](https://www.govtrack.us/).

# %%
pagerank_scores = nx.pagerank_numpy(bills)
#print top and bottom 5
sorted_pagerank = sorted(pagerank_scores.iteritems(), key=operator.itemgetter(1))

print "Lowest pagerank scores:" 
for senator in sorted_pagerank[0:5]: 
    print "%s: pagerank: %s, indegree: %s, outdegree: %s" % (senator[0], senator[1], (bills.in_degree([senator[0]])).values()[0], (bills.out_degree([senator[0]])).values()[0]) 

print
    
print "Highest pagerank scores:"
for senator in sorted_pagerank[-5:]: 
    print "%s: pagerank: %s, indegree: %s, outdegree: %s" % (senator[0], senator[1], (bills.in_degree([senator[0]])).values()[0], (bills.out_degree([senator[0]])).values()[0])
# Out:
# Lowest pagerank scores:
# Cowan, William M.: pagerank: 0.00145631067961, indegree: 0, outdegree: 22
# Sessions, Jeff: pagerank: 0.00145631067961, indegree: 0, outdegree: 33
# Scott, Tim: pagerank: 0.00145631067961, indegree: 0, outdegree: 27
# Booker, Cory A.: pagerank: 0.00145631067961, indegree: 0, outdegree: 3
# Chiesa, Jeff: pagerank: 0.00145631067961, indegree: 0, outdegree: 8
#
# Highest pagerank scores:
# Menendez, Robert: pagerank: 0.0258584781238, indegree: 78, outdegree: 35
# Lautenberg, Frank R.: pagerank: 0.0267752613091, indegree: 62, outdegree: 29
# Reid, Harry: pagerank: 0.0273201362992, indegree: 48, outdegree: 17
# Harkin, Tom: pagerank: 0.0286875338538, indegree: 88, outdegree: 43
# Brown, Sherrod: pagerank: 0.0294785305232, indegree: 92, outdegree: 46

# %%
#bills.tounderected
#make mst 
# size == raise to the power and multiply by a big size

#calculate centrality 
sorted_page_keys = [x[0] for x in sorted_pagerank]
sorted_page_values = [x[1] for x in sorted_pagerank]

in_degree = [(bills.in_degree([x])).values()[0] for x in sorted_page_keys]
out_degree = [(bills.out_degree([x])).values()[0] for x in sorted_page_keys]

#visualize centrality
fig = plt.figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(111)

plt.bar(range(len(sorted_page_keys)), sorted_page_values, align='center')
plt.xticks(range(len(sorted_page_keys)), sorted_page_keys, rotation=80, fontsize='small')
plt.xlabel("Senators by Pagerank Score")
plt.ylabel('Pagerank Score')
plt.show()

#visualize in and out degree

fig = plt.figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(111)

plt.bar(range(len(sorted_page_keys)), in_degree, align='center')
plt.xticks(range(len(sorted_page_keys)), sorted_page_keys, rotation=80, fontsize='small')
plt.xlabel("Senators organized by Pagerank Score")
plt.ylabel('In-degree')
plt.show()

fig = plt.figure(num=None, figsize=(18, 6), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(111)

plt.bar(range(len(sorted_page_keys)), out_degree, align='center')
plt.xticks(range(len(sorted_page_keys)), sorted_page_keys, rotation=80, fontsize='small')
plt.xlabel("Senators organized by Pagerank Score")
plt.ylabel('Out-degree')
plt.show()

# %% [markdown]
# As we see comparing the pagerank graph to the identically ordered in and out degree graphs, the pagerank is a pretty good prediction of who is a good leader. We see in the second graph some senators that really deviate from the trend, but overall they both slope upwards.
#
# We also see that the pagerank is pretty much unrelated to the outdegree, which is what we expect. Signing onto other people's bills doesn't really make you a leader.

# %% [markdown]
# ### Interactive Visualization
#
# Producing a good node link layout is not quite so simple. Nevertheless, we will give it a try.
#
# We will use [Gephi](https://gephi.org/) for interactive graph visualization. Gephi supports a wide variety of graph file formats, and NetworkX exports to several of them. We'll use the Graph Exchange XML Format (GEXF).

# %%
nx.write_gexf(votes, 'votes.gexf')

# %% [markdown]
# ### Problem 10: Analysis with Gephi
#
# Download and install [Gephi](https://gephi.org/). See the [lab](http://goo.gl/SzHioP) for a brief introduction. Load the exported votes file. Try to produce a layout that clearly separates Democrats from Republicans (hint: filter on edge weight and re-layout once you filtered). Run PageRank and some other statistics and try encoding them with node color and node size. Run the "Modularity" statistic and encode the results in color.
#
# Include a screenshot of your "best" visualization and embed the image here with `IPython.display.Image`. Make sure to include this image in your submission.
#
# Explain your observations. Is the network visualization very helpful? Try to visualize your LinkedIn network (see the lab) or the one provided in the lab. Which dataset is more suitable for visualization and why is there a difference?

# %%
from IPython.display import Image

path = 'gephishot.png'
Image(path)

# %% [markdown]
# First of all, working with the Gephi GUI reminded me of why CS179 exists... I think if Photoshop were open source, magazines would still show models with body fat...
#
# Now onto the network! I think this analysis is helpful- essentially we want to see who is "closest to the center" and this makes this loud and clear. We see Collins in the center, right where we expect him! In a sense, this graph is useful since it mirrors the layout we imagine on a senate floor. No one is disconnected from everyone else, but is one tangled, disfunctional glob.
#
# I wish I'd been able to get the results of PageRank to show up on my nodes, but unfortunately it wasn't working for me (also Preview wasn't working, so the image is a bit rough.)

# %% [markdown]
# ### How to Submit
#
# To submit your homework, create a folder named lastname_firstinitial_hw5 and place this notebook file in the folder. Double check that this file is still called HW5.ipynb, and that it contains your solutions. Also include any Gephi screenshots. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work.

# %% [markdown]
# ---
# *css tweaks in this cell*
# <style>
# div.text_cell_render {
#     line-height: 150%;
#     font-size: 110%;
#     width: 800px;
#     margin-left:50px;
#     margin-right:auto;
#     }
# </style>
